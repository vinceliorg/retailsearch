# %%
from elasticsearch import Elasticsearch
import math
import ast
import pystache
import json
es = Elasticsearch( 'http://localhost:9200/')

# %%
with open('configure/query_template.js','r') as f:
    query_template = json.load(f)

# %%
index_name = 'grocery-index'

# %%
def search(index_name, keywords,retrieval_boolean_operator='or', page=1, page_size=20):
    elastic_query = pystache.render(json.dumps(query_template), {'query': keywords, 'retrieval_boolean_operator':retrieval_boolean_operator })
    res = es.search(index=index_name, 
                    query=json.loads(elastic_query)['query'],from_ = page_size*(page-1),size = page_size)
    return res['hits']

# %%
search(index_name, '1kg potato')
# Out:
# {'total': {'value': 577, 'relation': 'eq'},
#  'max_score': 912.0464,
#  'hits': [{'_index': 'grocery-index',
#    '_id': '4f47b38af4d867f8a408dec39265b7ca',
#    '_score': 912.0464,
#    '_source': {'id': '4f47b38af4d867f8a408dec39265b7ca',
#     'title': 'Coles Brushed Baby Potato | 1kg',
#     'source': 'COLES',
#     'pricetext': '$3.00',
#     'price': 3.0,
#     'packageprice': '$3.00 per 1kg',
#     'productimage': 'https://productimages.coles.com.au/productimages/2/2517630.jpg',
#     'productdetails': 'BABY BRUSHED POTATOES Kitchen Performance: A minimum of 3 black bars gives you the best results when you are looking to : BAKE III BOIL IIIII DEEP FRY III MASH IIIII MICROWAVE IIII ROAST IIII AIR FRY IIII',
#     'url': 'https://www.coles.com.au/product/coles-brushed-baby-potato-1kg-2517630'}},
#   {'_index': 'grocery-index',
#    '_id': '062fcf33f80693d31284083baa0261dc',
#    '_score': 912.0464,
#    '_source': {'id': '062fcf33f80693d31284083baa0261dc',
#     'title': 'McCain Frozen Mashed Potato | 1kg',
#     'source': 'COLES',
#     'pricetext': '$7.70',
#     'price': 7.7,
#     'packageprice': '$7.70 per 1kg',
#     'productimage': 'https://productimages.coles.com.au/productimages/3/3412489.jpg',
#     'productdetails': 'McCain Mash potatoes are beautifully creamy and more-ish. They make for a perfect side dish to any meal.',
#     'url': 'https://www.coles.com.au/product/mccain-frozen-mashed-potato-1kg-3412489'}},
#   {'_index': 'grocery-index',
#    '_id': '15e37a8a41639b3a1d444d5a21bae1df',
#    '_score': 903.94434,
#    '_source': {'id': '15e37a8a41639b3a1d444d5a21bae1df',
#     'title': 'Coles Frozen Potato French Fries | 1kg',
#     'source': 'COLES',
#     'pricetext': '$3.50',
#     'price': 3.5,
#     'packageprice': '$3.50 per 1kg',
#     'productimage': 'https://productimages.coles.com.au/productimages/5/52139.jpg',
#     'productdetails': 'Our French Fries Chips are made with 100% Australian grown potatoes. A thin and crispy golden chip, best to be enjoyed as a side or on its own.We are very proud of our Australian grown potatoes, sourced from various locations across the country. Our potatoes provide you with great quality produce, no matter what the season.',
#     'url': 'https://www.coles.com.au/product/coles-frozen-potato-french-fries-1kg-52139'}},
#   {'_index': 'grocery-index',
#    '_id': 'df9cad1256224c643b0ad4eb732aa95e',
#    '_score': 546.64984,
#    '_source': {'id': 'df9cad1256224c643b0ad4eb732aa95e',
#     'title': 'Praise Potato Salad Dressing | 330mL',
#     'source': 'COLES',
#     'pricetext': '$3.60',
#     'price': 3.6,
#     'packageprice': '$1.09 per 100mL',
#     'productimage': 'https://productimages.coles.com.au/productimages/2/2762022.jpg',
#     'productdetails': "The secret to potato salad? This delightfully creamy Praise Potato Salad Dressing. it's full of flavour and made with no artificial colours and flavours. Make your homemade potato salad extra delicious with this creamy buttermilk dressing. Made with a dash of chives and black pepper for maximum flavour. Not only great on potato salads, it can also be used in tuna sandwiches for an extra creamy touch. No artificial colours or flavours.  Make the perfect potato salad to bring to your next BBQ with Praise Potato Salad Dressing. Deliciously creamy with no artificial flavours.",
#     'url': 'https://www.coles.com.au/product/praise-potato-salad-dressing-330ml-2762022'}},
#   {'_index': 'grocery-index',
#    '_id': 'b74498be33e3b1ffdc83b7c353ad136f',
#    '_score': 546.47833,
#    '_source': {'id': 'b74498be33e3b1ffdc83b7c353ad136f',
#     'title': "Helga's Sweet Potato Wrap | 445g",
#     'source': 'COLES',
#     'pricetext': '$5.00',
#     'price': 5.0,
#     'packageprice': '$1.12 per 100g',
#     'productimage': 'https://productimages.coles.com.au/productimages/5/5862883.jpg',
#     'productdetails': "HELGA'S Sweet Potato Wraps are made with real sweet potato. Enjoy the taste of sweet potato and a touch of paprika with whatever takes your fancy. Wrap up your favorite flavours for any meal, at any time of the day. HELGA'S Sweet Potato<br /><br />Enjoy the taste of sweet potato and a touch of paprika with whatever takes your fancy. Wrap up your favorite flavours for any meal, at any time of the day. Made with real sweet potato. No added sugar, no artificial colours, flavours or preservatives. Source of fibre, source of protein. Lower in sodium (45% less sodium compared to 80% of leading wrap brands available in market (average of 580mg/100g June 2022)).",
#     'url': "https://www.coles.com.au/product/helga's-sweet-potato-wrap-445g-5862883"}},
#   {'_index': 'grocery-index',
#    '_id': '9f80c46d74e2f37fa5c0a1f307e3331c',
#    '_score': 545.6379,
#    '_source': {'id': '9f80c46d74e2f37fa5c0a1f307e3331c',
#     'title': 'Grand Italian Potato Gnocchi | 500g',
#     'source': 'COLES',
#     'pricetext': '$5.60',
#     'price': 5.6,
#     'packageprice': '$1.12 per 100g',
#     'productimage': 'https://productimages.coles.com.au/productimages/3/3776882.jpg',
#     'productdetails': 'Our Grand Italian range of gnocchi are specially made with steamed fresh potato to create fluffy pillows of delicious goodness! The range offers a variety of natural and traditional Italian flavours.  No preservatives or artificials, made with natural or fresh ingredients locally sourced, give the Grand Italian Gnocchi range its hand-made taste experience.Made with steamed fresh potato!',
#     'url': 'https://www.coles.com.au/product/grand-italian-potato-gnocchi-500g-3776882'}},
#   {'_index': 'grocery-index',
#    '_id': '6003b85a454193d7a2d600e9e1732c7a',
#    '_score': 545.55566,
#    '_source': {'id': '6003b85a454193d7a2d600e9e1732c7a',
#     'title': "Guzzi's Traditional Potato Gnocchi | 500g",
#     'source': 'COLES',
#     'pricetext': '$4.45',
#     'price': 4.45,
#     'packageprice': '$0.89 per 100g',
#     'productimage': 'https://productimages.coles.com.au/productimages/8/8520671.jpg',
#     'productdetails': "Guzzi's Traditional Potato Gnocchi is made with high grade potatoes with an 81% potato content in the whole pack. This gourmet gnocchi is 98% fat free and created with a rough texture which absorbs and holds sauces so you don't miss out on the authentic flavour.Australian family made and owned98% fat freeCooks in 2 minutesVegetarian friendlyPerfect for rich tomato sauces with meat",
#     'url': "https://www.coles.com.au/product/guzzi's-traditional-potato-gnocchi-500g-8520671"}},
#   {'_index': 'grocery-index',
#    '_id': '1a536aa5b99c7822e7ef9ccaa340a50f',
#    '_score': 545.31067,
#    '_source': {'id': '1a536aa5b99c7822e7ef9ccaa340a50f',
#     'title': 'Calbee Pizza Potato Chips | 55g',
#     'source': 'COLES',
#     'pricetext': '$3.50',
#     'price': 3.5,
#     'packageprice': '$6.36 per 100g',
#     'productimage': 'https://productimages.coles.com.au/productimages/3/3728154.jpg',
#     'productdetails': "Take your taste buds on a journey with Calbee's Pizza Flavoured Potato Chip. These delicious potato chips are way beyond the ordinary. Each product is inspired by your favourite flavours and dishes from around the world. You'll never be bored by snacks again. Be sure to grab a pack for your next party or BBQ and share it with your friends and family. Take your taste buds on an international adventure with these flavoursome crisps.",
#     'url': 'https://www.coles.com.au/product/calbee-pizza-potato-chips-55g-3728154'}},
#   {'_index': 'grocery-index',
#    '_id': '564f31f0d3f1e07ead2ad546c8ed04df',
#    '_score': 544.7075,
#    '_source': {'id': '564f31f0d3f1e07ead2ad546c8ed04df',
#     'title': 'Thins Chicken Potato Chips | 175g',
#     'source': 'COLES',
#     'pricetext': '$4.70',
#     'price': 4.7,
#     'packageprice': '$2.69 per 100g',
#     'productimage': 'https://productimages.coles.com.au/productimages/6/6833950.jpg',
#     'productdetails': 'Thins are the original thin cut potato chip! Whether sharing or entertaining, Thins are cut just right to create the perfect light crispy texture that melts in your mouth. Proudly made in Australia. Gluten Free.',
#     'url': 'https://www.coles.com.au/product/thins-chicken-potato-chips-175g-6833950'}},
#   {'_index': 'grocery-index',
#    '_id': 'f754b2db2f49c7eb9b56b26493e2c84c',
#    '_score': 544.1221,
#    '_source': {'id': 'f754b2db2f49c7eb9b56b26493e2c84c',
#     'title': 'Coles Kitchen Potato Gnocchi | 500g',
#     'source': 'COLES',
#     'pricetext': '$4.60',
#     'price': 4.6,
#     'packageprice': '$0.92 per 100g',
#     'productimage': 'https://productimages.coles.com.au/productimages/3/3167363.jpg',
#     'productdetails': 'KITCHEN INSPIRED CREATIONSFrom our kitchen to yours......Experience the taste of Italy at home.We have blended fresh Australian potato and free range egg with flour to create pillows of soft gnocchi, ready to serve with a sauce of your choice. A delicious meal, full of flavour and ready in minutes',
#     'url': 'https://www.coles.com.au/product/coles-kitchen-potato-gnocchi-500g-3167363'}},
#   {'_index': 'grocery-index',
#    '_id': '7dccc824be9fef784e12aedd88ae9dbd',
#    '_score': 543.7402,
#    '_source': {'id': '7dccc824be9fef784e12aedd88ae9dbd',
#     'title': 'Kettle Potato Chips Chilli | 300g',
#     'source': 'COLES',
#     'pricetext': '$5.50',
#     'price': 5.5,
#     'packageprice': '$1.83 per 100g',
#     'productimage': 'https://productimages.coles.com.au/productimages/4/4992497.jpg',
#     'productdetails': "Chilli flavoured potato chipsWe take our chillies seriously, so our famous chilli flavour is created from a blend of exotic peppers, including the rich flavours of Spanish jalapenos.Vegan Friendly****We don't use any animal products in the preparation of these chips. Just so you are aware, they are cooked in the same facility as other products that are not vegan.",
#     'url': 'https://www.coles.com.au/product/kettle-potato-chips-chilli-300g-4992497'}},
#   {'_index': 'grocery-index',
#    '_id': '2490c122c27765e05de5848054c66e3f',
#    '_score': 543.7402,
#    '_source': {'id': '2490c122c27765e05de5848054c66e3f',
#     'title': 'OBAP Sweet Potato Noodles | 100g',
#     'source': 'COLES',
#     'pricetext': '$2.30',
#     'price': 2.3,
#     'packageprice': '$2.30 per 100g',
#     'productimage': 'https://productimages.coles.com.au/productimages/2/2017434.jpg',
#     'productdetails': "Dangmyeon, 'glass noodles' in Korean, are made from sweet potatoes. When cooked they become translucent with a chewy texture. Perfect for stir-fry and soup. Japchae literally translates to 'mixed & stirred' and there's not much more than that. Simply mix Obap Sweet Potato Noodles with vegetables and marinated beef, creating a stir-fry that you'll be sure to cook again and again.",
#     'url': 'https://www.coles.com.au/product/obap-sweet-potato-noodles-100g-2017434'}},
#   {'_index': 'grocery-index',
#    '_id': '3859c5f209c4e7a7de243580837656c2',
#    '_score': 543.43933,
#    '_source': {'id': '3859c5f209c4e7a7de243580837656c2',
#     'title': 'Pringles Cheese Potato Chips | 134g',
#     'source': 'COLES',
#     'pricetext': '$4.00',
#     'price': 4.0,
#     'packageprice': '$2.99 per 100g',
#     'productimage': 'https://productimages.coles.com.au/productimages/5/5355466.jpg',
#     'productdetails': "Discover the incredible flavour of Pringles. Our chips are uniquely shaped and perfectly seasoned!New Cheese flavour is deliciously big on taste and will be loved by everyone in the household.It's the ideal party snack to enjoy and tempt your friends, family or colleagues.Well seasoned to complement that rich potato tasteVegetarianA classic cheese flavourComes in a resealable canGreat for on-the-go snackingA delicious flavour experience to share with your friends.",
#     'url': 'https://www.coles.com.au/product/pringles-cheese-potato-chips-134g-5355466'}},
#   {'_index': 'grocery-index',
#    '_id': '0666649444b5f914b29ae5bbd61b7223',
#    '_score': 542.38336,
#    '_source': {'id': '0666649444b5f914b29ae5bbd61b7223',
#     'title': 'Healtheries Kidscare Potato Stix Roast | 120g',
#     'source': 'COLES',
#     'pricetext': '$5.00',
#     'price': 5.0,
#     'packageprice': '$4.17 per 100g',
#     'productimage': 'https://productimages.coles.com.au/productimages/3/3861450.jpg',
#     'productdetails': "Potato Stix are a funny bunch - they're always trying to disguise themselves! They may look like French fries but don't be fooled they taste like the crunchiest potato chips you've ever munched! Potato Stix are baked, not fried so they contain 50% less fat than regular potato chips. Then they're seasoned with delicious natural flavours, making them the perfect snack for the whole family!Baked not fried50% less fat than regular potato chipsNatural flavourLunchbox friendlyLow sugarRoast potato flavoured potato & rice snacks.",
#     'url': 'https://www.coles.com.au/product/healtheries-kidscare-potato-stix-roast-120g-3861450'}},
#   {'_index': 'grocery-index',
#    '_id': 'e28bd9172ff47b0ebdcfceebb6eb2528',
#    '_score': 542.1416,
#    '_source': {'id': 'e28bd9172ff47b0ebdcfceebb6eb2528',
#     'title': 'Healtheries Kidscare Potato Stix Funmix | 240g',
#     'source': 'COLES',
#     'pricetext': '$8.50',
#     'price': 8.5,
#     'packageprice': '$3.54 per 100g',
#     'productimage': 'https://productimages.coles.com.au/productimages/3/3861460.jpg',
#     'productdetails': "Potato Stix are a funny bunch - they're always trying to disguise themselves! They may look like French fries but don't be fooled... they taste like the crunchiest potato chips you've ever munched! Potato Stix are baked, not fried, so they contain 50% less fat than regular potato chips. Then they're seasoned with delicious natural flavours, making them the perfect snack for the whole family!Baked not fried50% less fat than regular potato chipsNatural flavourLunchbox friendlyLow sugarPotato & rice snacks.",
#     'url': 'https://www.coles.com.au/product/healtheries-kidscare-potato-stix-funmix-240g-3861460'}},
#   {'_index': 'grocery-index',
#    '_id': '9388cc08c068b7a1cd2f1941e658eb4f',
#    '_score': 541.59326,
#    '_source': {'id': '9388cc08c068b7a1cd2f1941e658eb4f',
#     'title': 'Ollies Kitchen Gnocchi Sweet Potato | 400g',
#     'source': 'COLES',
#     'pricetext': '$3.95',
#     'price': 3.95,
#     'packageprice': '$0.99 per 100g',
#     'productimage': 'https://productimages.coles.com.au/productimages/3/3945185.jpg',
#     'productdetails': 'Ollies Kitchn Sweet Potato Gnocchi is traditional Italian gnocchi made with quality ingredients. With a delicate sweet potato flavour, just add fresh herbs, your favourite sauce, a sprinkle of cheese and youve got a quick, delicious meal!',
#     'url': 'https://www.coles.com.au/product/ollies-kitchen-gnocchi-sweet-potato-400g-3945185'}},
#   {'_index': 'grocery-index',
#    '_id': '940b1fdace68cdfc314a0157930584bb',
#    '_score': 541.2377,
#    '_source': {'id': '940b1fdace68cdfc314a0157930584bb',
#     'title': 'Coles Kitchen Classic Potato Salad | 400g',
#     'source': 'COLES',
#     'pricetext': '$5.00',
#     'price': 5.0,
#     'packageprice': '$12.50 per 1kg',
#     'productimage': 'https://productimages.coles.com.au/productimages/5/5508024.jpg',
#     'productdetails': 'Potato Salad with parsley and spring onion in a creamy dressing',
#     'url': 'https://www.coles.com.au/product/coles-kitchen-classic-potato-salad-400g-5508024'}},
#   {'_index': 'grocery-index',
#    '_id': '664de9fde4550972849fe961f3fca6f1',
#    '_score': 541.1965,
#    '_source': {'id': '664de9fde4550972849fe961f3fca6f1',
#     'title': 'McCain Frozen Sweet Potato Chips | 750g',
#     'source': 'COLES',
#     'pricetext': '$6.20',
#     'price': 6.2,
#     'packageprice': '$8.27 per 1kg',
#     'productimage': 'https://productimages.coles.com.au/productimages/2/2137800.jpg',
#     'productdetails': 'McCain Sweet Potato chips are wholesome and tasty, just like home made.',
#     'url': 'https://www.coles.com.au/product/mccain-frozen-sweet-potato-chips-750g-2137800'}},
#   {'_index': 'grocery-index',
#    '_id': 'a58390edfcf269d46460e30594d61bb8',
#    '_score': 541.1142,
#    '_source': {'id': 'a58390edfcf269d46460e30594d61bb8',
#     'title': 'Coles Sweet Potato Cottage Pie | 375g',
#     'source': 'COLES',
#     'pricetext': '$3.30',
#     'price': 3.3,
#     'packageprice': '$0.88 per 100g',
#     'productimage': 'https://productimages.coles.com.au/productimages/3/3230914.jpg',
#     'productdetails': 'Coles Delicious Australian minced beef casserole with vegetables & gravy, topped with sweet potato mash',
#     'url': 'https://www.coles.com.au/product/coles-sweet-potato-cottage-pie-375g-3230914'}},
#   {'_index': 'grocery-index',
#    '_id': '386e19b938ed33709b539d879e05ddb0',
#    '_score': 540.8713,
#    '_source': {'id': '386e19b938ed33709b539d879e05ddb0',
#     'title': 'Calbee Hot & Spicy Potato Chips | 55g',
#     'source': 'COLES',
#     'pricetext': '$3.50',
#     'price': 3.5,
#     'packageprice': '$6.36 per 100g',
#     'productimage': 'https://productimages.coles.com.au/productimages/3/3728187.jpg',
#     'productdetails': "Take your tastebuds on a journey with Calbee's Hot  Spicy flavoured Potato Chips. These delicious potato chips are way beyond the ordinary. Each product is inspired by your favourite flavours and dishes from around the world. You'll never be bored by snacks again. Be sure to grab a pack for your next party or BBQ and share it with your friends and family. Take your taste buds on an international adventrue with these flavoursome crisps.",
#     'url': 'https://www.coles.com.au/product/calbee-hot-and-spicy-potato-chips-55g-3728187'}}]}
